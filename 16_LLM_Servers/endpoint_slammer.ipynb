# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/fireworks/models/gpt-oss-20b"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x111757390>
# Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x111755e50>
# **Short answer:** It’s a trick question – there’s no real “wood‑chuck” in the wild to test, so the answer is all in good fun.
#
# **The classic tongue‑twister version**
# > *“A wood‑chuck would chuck… a wood‑chuck would chuck… an entire chunk of human orange gob – about 700 pounds (roughly 30–35 cubic feet) of wood, if it fancied the work.”*
#
# **A science‑inspired take**
# Dr. Richard Thomas (1995) measured the amount of soil a woodchuck could move in a day and found it to be about **700 lb** of dirt. If we translate “dirt” into “wood” (roughly the same bulk density for a splintered log), that’s also around **700 lb** of wood – or about **30–35 cubic feet**.
#
# **But really**
# Groundhogs (the real‑life “woodchucks”) don’t chuck wood at all – they dig burrows, eat vegetation, and occasionally munch on bark. The rhyme is meant to be a linguistic joke, not a physics challenge.
#
# So, in the world of whimsy: *a woodchuck would chuck as much wood as it could, but that “could” is just a clever play on words.*

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Request 4 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-55530184f995490e9ee5f36193ef13ad"}
# Request 12 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-8558e26988074af4897d4ece66be3753"}
# Request 7 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-138d0b182aad407ea50a3acadbd4c4e0"}
# Request 17 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-c465e6fba9f24648b093ac4c02eedcea"}
# Request 20 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-7c890c9cc230403cb9654044bba517f5"}
# Request 11 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-52f5e250cf924935953bdd75661aa461"}
# Request 6 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-32287b12bacc46599302c1df833280f6"}
# Request 2 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-7835e4495af24e5ebf48bb2a6150b6cf"}
# Request 14 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-5bbeefa4d8c649de91faf04d7e6647a1"}
# Request 18 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-6b593c9174da47e0a5f8092d9da95fe6"}
# Request 15 failed: {"error":{"message":"You have exceeded your rate limit for this API. Please try again later. For more information, see https://docs.fireworks.ai/guides/quotas_usage/rate-limits.","param":null,"code":"RATE_LIMIT_EXCEEDED","type":"error"},"request_id":"chatcmpl-c5ebc3519c6846719e674fb94f3541cb"}
# Response 13: A fun tongue‑twister with no real answer—but if we play alon...
# Response 24: A classic tongue‑twister with a surprisingly *scientific* an...
# Response 21: About 700 pounds—so roughly 0.7 tonne—as the most popular fo...
# Response 1: Ah, the age‑old “how much wood” conundrum! 🎶🪵
#
# **A classic (...
# Response 9: If a wood‑chuck could actually chuck wood, the answer would ...
# Response 22: "If a woodchuck could chuck wood, it would chuck as much woo...
# Response 10: The classic tongue‑twister doesn’t actually have a precise s...
# Response 16: It’s one of those tongue‑twisters that has been playfully “a...
# Response 19: That classic line isn’t a question anyone took seriously for...
# Response 23: **Answer (the classic folklore / “chat” version)**
# > If a ...
# Response 8: Ah, the classic tongue‑twister and self‑referential riddle t...
# Response 3: **Short answer:** About 700 – 800 pounds (roughly the equiva...
# Response 5: `Na’cho’ i eka’wood‑chuck iahco?`
# `Måsi, si i wood‑chuck i...
